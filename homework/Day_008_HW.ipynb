# %% [markdown]
# # [作業目標]
# - 對資料做更多處理 : 顯示特定欄位的統計值與直方圖

# %% [markdown]
# # [作業重點]
# - 試著顯示特定欄位的基礎統計數值 (In[4], Out[4], Hint : describe())
# - 試著顯示特定欄位的直方圖 (In[5], Out[5], Hint : .hist())

# %%
import pandas as pd
import numpy as np


x=np.array([5,2,7,1,6])
y=np.array([10,5,15,4,12])
#a=concat(x,y)


print(x.cumsum())
x_mean=4.2
y_mean=9.2
# Out:
# [ 5  7 14 15 21]

# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd

# 設定 data_path
dir_data = './data/'

# %%
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)
#print(app_train.head())

#df=pd.DataFrame(app_train.head())
df1=app_train.head().iloc[6:7]
print(df1.head())
#df["AMT_INCOME_TOTAL"]


#df = df.groupby("AMT_INCOME_TOTAL").aggregate('count').reset_index()
# Out:
# Empty DataFrame
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt=df["AMT_INCOME_TOTAL"].plot()
plt.set_xlabel("AMT_INCOME_TOTAL")
plt.set_ylabel("AMT_CREDIT")
plt.set_title("AMT_INCOME_TOTAL&AMT_CREDIT")
# Out:
# Text(0.5, 1.0, 'AMT_INCOME_TOTAL&AMT_CREDIT')

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)
